# %%
from model.model import explore_the_best_shuttle_bus_path

# %%
explore_the_best_shuttle_bus_path("대전")
# Out:
# 대전지역 최적의 셔틀 노선
# 최적의 셔틀 노선: ['대전광역시 유성구', '대전광역시 서구', '대전광역시 대덕구', '대전광역시 중구', '전라북도 무주군'] | 총 거리: 65.75 km | 총 시간: 1.0시간 22분 | 총 가중치: 0.3848355263754449 | threshold: 1.38
# 최적의 셔틀 노선: ['대전광역시 서구', '대전광역시 유성구', '대전광역시 대덕구', '대전광역시 중구', '전라북도 무주군'] | 총 거리: 69.12 km | 총 시간: 1.0시간 22분 | 총 가중치: 0.3824432309532963 | threshold: 1.38
# 최적의 셔틀 노선: ['세종특별자치시', '대전광역시 유성구', '대전광역시 대덕구', '대전광역시 중구', '전라북도 무주군'] | 총 거리: 82.69 km | 총 시간: 1.0시간 37분 | 총 가중치: 0.3824432309532963 | threshold: 1.39
# 최적의 셔틀 노선: ['세종특별자치시', '대전광역시 유성구', '대전광역시 서구', '대전광역시 대덕구', '전라북도 무주군'] | 총 거리: 84.39 km | 총 시간: 1.0시간 38분 | 총 가중치: 0.5268761569923317 | threshold: 1.42
# 최적의 셔틀 노선: ['세종특별자치시', '대전광역시 유성구', '대전광역시 서구', '대전광역시 중구', '전라북도 무주군'] | 총 거리: 81.65 km | 총 시간: 1.0시간 38분 | 총 가중치: 0.5283189651065366 | threshold: 1.42
# 최적의 셔틀 노선: ['세종특별자치시', '대전광역시 서구', '대전광역시 대덕구', '대전광역시 중구', '전라북도 무주군'] | 총 거리: 82.53 km | 총 시간: 1.0시간 40분 | 총 가중치: 0.3848355263754449 | threshold: 1.44
# ...

# %%
explore_the_best_shuttle_bus_path("전북")
# Out:
# 전북지역 최적의 셔틀 노선
# 최적의 셔틀 노선: ['전라북도 군산시', '전라북도 전주시 덕진구', '전라북도 전주시 완산구', '전라북도 진안군', '전라북도 무주군'] | 총 거리: 129.75 km | 총 시간: 2.0시간 22분 | 총 가중치: 0.5330279727694249 | threshold: 1.42
# 최적의 셔틀 노선: ['전라북도 군산시', '전라북도 전주시 완산구', '전라북도 전주시 덕진구', '전라북도 진안군', '전라북도 무주군'] | 총 거리: 137.88 km | 총 시간: 2.0시간 26분 | 총 가중치: 0.5330279727694249 | threshold: 1.45
# 최적의 셔틀 노선: ['전라북도 군산시', '전라북도 익산시', '전라북도 전주시 덕진구', '전라북도 진안군', '전라북도 무주군'] | 총 거리: 129.95 km | 총 시간: 2.0시간 26분 | 총 가중치: 0.39120694829924235 | threshold: 1.46
# 최적의 셔틀 노선: ['전라북도 군산시', '전라북도 익산시', '전라북도 전주시 덕진구', '전라북도 전주시 완산구', '전라북도 무주군'] | 총 거리: 127.83 km | 총 시간: 2.0시간 28분 | 총 가중치: 0.5207810677200055 | threshold: 1.47
# 최적의 셔틀 노선: ['전라북도 익산시', '전라북도 전주시 덕진구', '전라북도 전주시 완산구', '전라북도 진안군', '전라북도 무주군'] | 총 거리: 113.67 km | 총 시간: 2.0시간 14분 | 총 가중치: 0.5330279727694249 | threshold: 1.47
# 최적의 셔틀 노선: ['전라북도 익산시', '전라북도 전주시 완산구', '전라북도 전주시 덕진구', '전라북도 진안군', '전라북도 무주군'] | 총 거리: 120.55 km | 총 시간: 2.0시간 16분 | 총 가중치: 0.5330279727694249 | threshold: 1.49
# ...
