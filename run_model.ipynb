# %%
from model.model import explore_the_best_shuttle_bus_path

# %%
explore_the_best_shuttle_bus_path("대전")
# Out:
# load od data: 100%|██████████| 10/10 [00:17<00:00,  1.75s/file]
# 대전 지역 최적의 셔틀 노선
#   1순위 | 셔틀 노선: 대전광역시 유성구 -> 대전광역시 서구 -> 대전광역시 대덕구 -> 전라북도 무주군     | 총 거리: 71.70 km   | 총 시간: 1.0시간 15분  | 총 가중치: 0.30422039022524006 | threshold: 1.30
#   2순위 | 셔틀 노선: 대전광역시 서구 -> 대전광역시 유성구 -> 대전광역시 대덕구 -> 전라북도 무주군     | 총 거리: 74.74 km   | 총 시간: 1.0시간 16분  | 총 가중치: 0.3018280948030915 | threshold: 1.30
#   3순위 | 셔틀 노선: 대전광역시 서구 -> 대전광역시 대덕구 -> 대전광역시 중구 -> 전라북도 무주군      | 총 거리: 62.37 km   | 총 시간: 1.0시간 14분  | 총 가중치: 0.15978746418620465 | threshold: 1.30
#   4순위 | 셔틀 노선: 대전광역시 서구 -> 대전광역시 중구 -> 대전광역시 대덕구 -> 전라북도 무주군      | 총 거리: 73.28 km   | 총 시간: 1.0시간 16분  | 총 가중치: 0.15978746418620465 | threshold: 1.30
#   5순위 | 셔틀 노선: 세종특별자치시 -> 대전광역시 유성구 -> 대전광역시 서구 -> 전라북도 무주군       | 총 거리: 88.24 km   | 총 시간: 1.0시간 33분  | 총 가중치: 0.4477038289563318 | threshold: 1.40
#   6순위 | 셔틀 노선: 세종특별자치시 -> 대전광역시 유성구 -> 대전광역시 대덕구 -> 전라북도 무주군      | 총 거리: 88.31 km   | 총 시간: 1.0시간 32분  | 총 가중치: 0.3018280948030915 | threshold: 1.40
#   7순위 | 셔틀 노선: 세종특별자치시 -> 대전광역시 유성구 -> 대전광역시 중구 -> 전라북도 무주군       | 총 거리: 80.77 km   | 총 시간: 1.0시간 34분  | 총 가중치: 0.3032709029172964 | threshold: 1.40
#   8순위 | 셔틀 노선: 세종특별자치시 -> 대전광역시 서구 -> 대전광역시 유성구 -> 전라북도 무주군       | 총 거리: 96.46 km   | 총 시간: 1.0시간 36분  | 총 가중치: 0.4477038289563318 | threshold: 1.40
#   9순위 | 셔틀 노선: 세종특별자치시 -> 대전광역시 서구 -> 대전광역시 대덕구 -> 전라북도 무주군       | 총 거리: 88.49 km   | 총 시간: 1.0시간 34분  | 총 가중치: 0.30422039022524006 | threshold: 1.40
#  10순위 | 셔틀 노선: 세종특별자치시 -> 대전광역시 서구 -> 대전광역시 중구 -> 전라북도 무주군        | 총 거리: 81.05 km   | 총 시간: 1.0시간 35분  | 총 가중치: 0.305663198339445 | threshold: 1.40

# %%
explore_the_best_shuttle_bus_path("전북")
# Out:
# load od data: 100%|██████████| 10/10 [00:17<00:00,  1.75s/file]
# 전북 지역 최적의 셔틀 노선
#   1순위 | 셔틀 노선: 전라북도 군산시 -> 전라북도 전주시 덕진구 -> 전라북도 전주시 완산구 -> 전라북도 무주군 | 총 거리: 118.88 km  | 총 시간: 2.0시간 11분  | 총 가중치: 0.44067941983836 | threshold: 1.30
#   2순위 | 셔틀 노선: 전라북도 군산시 -> 전라북도 전주시 덕진구 -> 전라북도 진안군 -> 전라북도 무주군   | 총 거리: 121.00 km  | 총 시간: 2.0시간 9분   | 총 가중치: 0.31110530041759676 | threshold: 1.30
#   3순위 | 셔틀 노선: 전라북도 익산시 -> 전라북도 전주시 덕진구 -> 전라북도 진안군 -> 전라북도 무주군   | 총 거리: 104.92 km  | 총 시간: 2.0시간 3분   | 총 가중치: 0.31110530041759676 | threshold: 1.30
#   4순위 | 셔틀 노선: 전라북도 군산시 -> 전라북도 익산시 -> 전라북도 전주시 덕진구 -> 전라북도 무주군   | 총 거리: 119.07 km  | 총 시간: 2.0시간 14분  | 총 가중치: 0.2988583953681774 | threshold: 1.40
#   5순위 | 셔틀 노선: 전라북도 군산시 -> 전라북도 익산시 -> 전라북도 진안군 -> 전라북도 무주군       | 총 거리: 132.16 km  | 총 시간: 2.0시간 14분  | 총 가중치: 0.1724502008127105 | threshold: 1.40
#   6순위 | 셔틀 노선: 전라북도 군산시 -> 전라북도 전주시 완산구 -> 전라북도 전주시 덕진구 -> 전라북도 무주군 | 총 거리: 127.00 km  | 총 시간: 2.0시간 15분  | 총 가중치: 0.44067941983836 | threshold: 1.40
#   7순위 | 셔틀 노선: 전라북도 군산시 -> 전라북도 전주시 완산구 -> 전라북도 진안군 -> 전라북도 무주군   | 총 거리: 133.11 km  | 총 시간: 2.0시간 20분  | 총 가중치: 0.31427122528289314 | threshold: 1.40
#   8순위 | 셔틀 노선: 전라북도 익산시 -> 전라북도 전주시 완산구 -> 전라북도 전주시 덕진구 -> 전라북도 무주군 | 총 거리: 109.67 km  | 총 시간: 2.0시간 8분   | 총 가중치: 0.44067941983836 | threshold: 1.40
#   9순위 | 셔틀 노선: 전라북도 익산시 -> 전라북도 전주시 완산구 -> 전라북도 진안군 -> 전라북도 무주군   | 총 거리: 115.78 km  | 총 시간: 2.0시간 13분  | 총 가중치: 0.31427122528289314 | threshold: 1.40
#  10순위 | 셔틀 노선: 전라북도 익산시 -> 전라북도 전주시 덕진구 -> 전라북도 전주시 완산구 -> 전라북도 무주군 | 총 거리: 102.79 km  | 총 시간: 2.0시간 5분   | 총 가중치: 0.44067941983836 | threshold: 1.40
